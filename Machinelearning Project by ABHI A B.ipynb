# %% [markdown]
# ##IMPORT LIBRARIES

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## LOAD DATASET

# %%
# viewing the dataset

df= pd.read_csv("/content/airlines data.csv")

# %%
df
# Out:
#             id  Gender      Customer Type  Age   Type of Travel     Class  \
# 0        70172    Male     Loyal Customer   13  Personal Travel  Eco Plus
# 1         5047    Male  disloyal Customer   25  Business travel  Business
# 2       110028  Female     Loyal Customer   26  Business travel  Business
# 3        24026  Female     Loyal Customer   25  Business travel  Business
# 4       119299    Male     Loyal Customer   61  Business travel  Business
# ...        ...     ...                ...  ...              ...       ...
# 103899   94171  Female  disloyal Customer   23  Business travel       Eco
# 103900   73097    Male     Loyal Customer   49  Business travel  Business
# 103901   68825    Male  disloyal Customer   30  Business travel  Business
# 103902   54173  Female  disloyal Customer   22  Business travel       Eco
# 103903   62567    Male     Loyal Customer   27  Business travel  Business
#
#         Flight Distance  Inflight wifi service  \
# ...

# %% [markdown]
# ## DATA EXPLORATION

# %%
# shape of the dataset

df.shape
# Out:
# (103904, 24)

# %%
# statistical analysis

df.describe()
# Out:
#                   id            Age  Flight Distance  Inflight wifi service  \
# count  103904.000000  103904.000000    103904.000000          103904.000000
# mean    64924.210502      39.379706      1189.448375               2.729683
# std     37463.812252      15.114964       997.147281               1.327829
# min         1.000000       7.000000        31.000000               0.000000
# 25%     32533.750000      27.000000       414.000000               2.000000
# 50%     64856.500000      40.000000       843.000000               3.000000
# 75%     97368.250000      51.000000      1743.000000               4.000000
# max    129880.000000      85.000000      4983.000000               5.000000
#
#        Departure/Arrival time convenient  Ease of Online booking  \
# count                      103904.000000           103904.000000
# mean                            3.060296                2.756901
# std                             1.525075                1.398929
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103904 entries, 0 to 103903
# Data columns (total 24 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   id                                 103904 non-null  int64
#  1   Gender                             103904 non-null  object
#  2   Customer Type                      103904 non-null  object
#  3   Age                                103904 non-null  int64
#  4   Type of Travel                     103904 non-null  object
#  5   Class                              103904 non-null  object
#  6   Flight Distance                    103904 non-null  int64
#  7   Inflight wifi service              103904 non-null  int64
#  8   Departure/Arrival time convenient  103904 non-null  int64
#  9   Ease of Online booking             103904 non-null  int64
#  10  Gate location                      103904 non-null  int64
# ...

# %%
#checking for duplicated rows and deleting them

df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.drop_duplicates(inplace=True)

# %%
# checking for and correcting missing values(null values)

df.isnull().sum()
# Out:
# id                                     0
# Gender                                 0
# Customer Type                          0
# Age                                    0
# Type of Travel                         0
# Class                                  0
# Flight Distance                        0
# Inflight wifi service                  0
# Departure/Arrival time convenient      0
# Ease of Online booking                 0
# Gate location                          0
# Food and drink                         0
# Online boarding                        0
# Seat comfort                           0
# Inflight entertainment                 0
# On-board service                       0
# Leg room service                       0
# Baggage handling                       0
# Checkin service                        0
# Inflight service                       0
# Cleanliness                            0
# Departure Delay in Minutes             0
# Arrival Delay in Minutes             310
# ...

# %%
mode_cols = [
    'Type of Travel', 'Class', 'Inflight wifi service',
    'Departure/Arrival time convenient', 'Ease of Online booking',
    'Gate location', 'Food and drink', 'Online boarding', 'Seat comfort',
    'Inflight entertainment', 'On-board service', 'Leg room service',
    'Baggage handling', 'Checkin service', 'Inflight service',
    'Cleanliness', 'satisfaction'
]

for i in mode_cols:
    df[i] = df[i].fillna(df[i].mode()[0])

# %%
median_cols = ['Flight Distance', 'Departure Delay in Minutes', 'Arrival Delay in Minutes']

for i in median_cols:
    df[i] = df[i].fillna(df[i].median())

# %%
df.isnull().sum()
# Out:
# id                                   0
# Gender                               0
# Customer Type                        0
# Age                                  0
# Type of Travel                       0
# Class                                0
# Flight Distance                      0
# Inflight wifi service                0
# Departure/Arrival time convenient    0
# Ease of Online booking               0
# Gate location                        0
# Food and drink                       0
# Online boarding                      0
# Seat comfort                         0
# Inflight entertainment               0
# On-board service                     0
# Leg room service                     0
# Baggage handling                     0
# Checkin service                      0
# Inflight service                     0
# Cleanliness                          0
# Departure Delay in Minutes           0
# Arrival Delay in Minutes             0
# satisfaction                         0
# dtype: int64

# %%
# dropping unwanted columns
df = df.drop(columns=['id'])

# %% [markdown]
# ## EXPLORATORY DATA ANALYSIS

# %% [markdown]
# ### univariate

# %%
sns.countplot(data=df, x='satisfaction', hue='satisfaction', palette='Set1', legend=False)
plt.title("Distribution of Customer Satisfaction")
plt.xlabel("satisfaction level")
plt.ylabel("Number of Passengers")
plt.show()

# %% [markdown]
# #### observation from the chart:
#  More passengers are neutral or dissatisfied than satisfied.
# This indicates an overall lean toward lower satisfaction levels

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df['Age'], bins=35, kde=True, color='skyblue')

# Add vertical lines for mean and median
plt.axvline(df['Age'].mean(), color='red', linestyle='dashed', linewidth=2, label='Mean')
plt.axvline(df['Age'].median(), color='green', linestyle='dashed', linewidth=2, label='Median')

plt.title("Age Distribution")
plt.xlabel("Age")
plt.ylabel("Frequency")
plt.legend()
plt.show()

# %%
from scipy.stats import skew, kurtosis
age_skew = skew(df['Age'].dropna())
age_kurt = kurtosis(df['Age'].dropna())

print("Skewness of Age:", age_skew)
print("Kurtosis of Age:", age_kurt )
# Out:
# Skewness of Age: -0.004516061875455768
# Kurtosis of Age: -0.7195912358853982

# %% [markdown]
# #### observation from the graph:
# The age distribution is nearly symmetric with a skewness of approximately -0.0045, indicating no significant skew.
# The mean age and the median age are very close to each other.
# The kurtosis of around -0.72 suggests the distribution is slightly flatter (platykurtic) than a normal distribution.

# %% [markdown]
# ### bivariate

# %%
sns.countplot(data=df, x='Class', hue='satisfaction', palette='Set1')
plt.title("Satisfaction by Travel Class")
plt.xlabel("Travel Class")
plt.ylabel("Number of Passengers")
plt.legend(title='Satisfaction')
plt.show()

# %% [markdown]
# #### observation from the graph:
# Most passengers travelled in eco class but the majority of them were neutral or dissatisfied.
# The number of satisfied passengers is significantly higher than neutral or dissatisfied passengers.
# Eco plus had fewest passengerS, with a slightly higher number being neutral or dissatisfied

# %%
sns.boxplot(data=df,
            x='Type of Travel',
            y='Flight Distance',
            hue='Type of Travel',
            palette=['green', 'lightgreen'],
            legend=False)
plt.title("Flight Distance by Type of Travel")
plt.xlabel("Type of Travel")
plt.ylabel("Flight Distance")
plt.show()

# %% [markdown]
# #### observation from the plot:
# Business travel tends to have a higher median flight distance than personal travel. Personal travel shows many outliers. IQR is wider for business travel, showing more variation in flight distances.

# %% [markdown]
# ### multivariate

# %%
numeric = df.select_dtypes(include=['int64', 'float64'])
correlation_matrix = numeric.corr()

# %%
plt.figure(figsize=(20, 10))
sns.heatmap(correlation_matrix, annot=True, fmt=".2f",cmap='YlGnBu', square=True)
plt.title("Correlation Heatmap of Numerical Features")
plt.show()

# %% [markdown]
# ## FEATURE ENGINEERING

# %%
# outlier detection and its correction

numerical_cols = ['Age', 'Flight Distance', 'Departure Delay in Minutes', 'Arrival Delay in Minutes']
for i in numerical_cols:
    plt.figure(figsize=(10, 5))
    sns.boxplot(y=df[i], color='skyblue')
    plt.title("Boxplot of " + i)
    plt.show()

# %%
for i in numerical_cols:
    Q1 = df[i].quantile(0.25)
    Q3 = df[i].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR


    outliers = df[(df[i] < lower_bound) | (df[i] > upper_bound)]
    print("\nColumn:", i)
    print("IQR:", IQR)
    print("Lower Bound:", lower_bound)
    print("Upper Bound:", upper_bound)



    df[i] = df[i].clip(lower=lower_bound, upper=upper_bound)
# Out:
# Column: Age
# IQR: 24.0
# Lower Bound: -9.0
# Upper Bound: 87.0
#
# Column: Flight Distance
# IQR: 1329.0
# Lower Bound: -1579.5
# Upper Bound: 3736.5
#
# Column: Departure Delay in Minutes
# IQR: 12.0
# Lower Bound: -18.0
# Upper Bound: 30.0
#
# Column: Arrival Delay in Minutes
# IQR: 13.0
# Lower Bound: -19.5
# Upper Bound: 32.5

# %% [markdown]
# ## DATA PREPROCESSING

# %%
# unique values per feature

ordinal_cols = ['Inflight wifi service','Departure/Arrival time convenient','Ease of Online booking','Gate location','Food and drink','Online boarding','Seat comfort','Inflight entertainment','On-board service','Leg room service',
'Baggage handling','Inflight service', 'Checkin service', 'Cleanliness']

for i in ordinal_cols:
    print("\nColumn:", i)
    print("Data type:", df[i].dtype)
    print("Number of unique values:", df[i].nunique())
    print("Unique values:", df[i].unique())
# Out:
# Column: Inflight wifi service
# Data type: int64
# Number of unique values: 6
# Unique values: [3 2 4 1 5 0]
#
# Column: Departure/Arrival time convenient
# Data type: int64
# Number of unique values: 6
# Unique values: [4 2 5 3 1 0]
#
# Column: Ease of Online booking
# Data type: int64
# Number of unique values: 6
# Unique values: [3 2 5 4 1 0]
#
# Column: Gate location
# Data type: int64
# Number of unique values: 6
# Unique values: [1 3 2 5 4 0]
#
# Column: Food and drink
# Data type: int64
# Number of unique values: 6
# Unique values: [5 1 2 4 3 0]
#
# Column: Online boarding
# Data type: int64
# Number of unique values: 6
# Unique values: [3 5 2 1 4 0]
#
# Column: Seat comfort
# Data type: int64
# Number of unique values: 6
# Unique values: [5 1 2 3 4 0]
#
# Column: Inflight entertainment
# Data type: int64
# Number of unique values: 6
# Unique values: [5 1 2 3 4 0]
#
# Column: On-board service
# Data type: int64
# Number of unique values: 6
# Unique values: [4 1 2 3 5 0]
#
# ...

# %%
categorical_cols = ['Gender', 'Customer Type', 'Type of Travel', 'Class', 'satisfaction']

for i in categorical_cols:
    print("\nColumn:", i)
    print("Data type:", df[i].dtype)
    print("Number of unique values:", df[i].nunique())
    print("Unique values:", df[i].unique())
# Out:
# Column: Gender
# Data type: object
# Number of unique values: 2
# Unique values: ['Male' 'Female']
#
# Column: Customer Type
# Data type: object
# Number of unique values: 2
# Unique values: ['Loyal Customer' 'disloyal Customer']
#
# Column: Type of Travel
# Data type: object
# Number of unique values: 2
# Unique values: ['Personal Travel' 'Business travel']
#
# Column: Class
# Data type: object
# Number of unique values: 3
# Unique values: ['Eco Plus' 'Business' 'Eco']
#
# Column: satisfaction
# Data type: object
# Number of unique values: 2
# Unique values: ['neutral or dissatisfied' 'satisfied']

# %%
# encoding categorical data

data=pd.get_dummies(df,drop_first=True).astype(int)

# %%
data
# Out:
#         Age  Flight Distance  Inflight wifi service  \
# 0        13              460                      3
# 1        25              235                      3
# 2        26             1142                      2
# 3        25              562                      2
# 4        61              214                      3
# ...     ...              ...                    ...
# 103899   23              192                      2
# 103900   49             2347                      4
# 103901   30             1995                      1
# 103902   22             1000                      1
# 103903   27             1723                      1
#
#         Departure/Arrival time convenient  Ease of Online booking  \
# 0                                       4                       3
# 1                                       2                       3
# 2                                       2                       2
# 3                                       5                       5
# ...

# %%
x=data.drop(columns=['satisfaction_satisfied'])
y=data['satisfaction_satisfied']

# %%
from sklearn.model_selection import train_test_split

# %%
#splitting your data into training and testing set

xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
xtrain
# Out:
#         Age  Flight Distance  Inflight wifi service  \
# 20921    59             1046                      4
# 36897    40              752                      4
# 8468     65              383                      2
# 53490    70             2239                      3
# 78687    25             1358                      2
# ...     ...              ...                    ...
# 54886    39              637                      3
# 76820    17              646                      3
# 103694   46             1197                      1
# 860      37              320                      5
# 15795    14              351                      4
#
#         Departure/Arrival time convenient  Ease of Online booking  \
# 20921                                   5                       4
# 36897                                   4                       4
# 8468                                    3                       2
# 53490                                   5                       3
# ...

# %%
# Scaling of Data using StandardScaler

from sklearn.preprocessing import OneHotEncoder, LabelEncoder, StandardScaler

# %%
sc=StandardScaler()

# %%
xtrain=sc.fit_transform(xtrain)
xtest=sc.transform(xtest)

# %% [markdown]
# ## MODEL EVALUATION

# %%
#Model Selection and Hyperparameter Grid Setup

from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier , GradientBoostingClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier

# %%
models = {
    'Logistic Regression': LogisticRegression(max_iter=1000),
    'Decision Tree Classifier': DecisionTreeClassifier(),
    'Random Forest Classifier': RandomForestClassifier(),
    'Gradient Boosting Classifier': GradientBoostingClassifier(),
    'SVC': SVC(),
    'KNN Classifier': KNeighborsClassifier()
}

param_grid = {
    'Logistic Regression': {
        'penalty': ['l2'],
        'C': [0.1, 1, 10],
        'solver': ['lbfgs']
    },
    'Decision Tree Classifier': {
        'max_depth': [None, 5, 10, 20],
        'min_samples_split': [2, 5, 10]
    },
    'Random Forest Classifier': {
        'n_estimators': [50, 100],
        'max_depth': [None, 10, 20],
        'min_samples_split': [2, 5]
    },
    'Gradient Boosting Classifier': {
        'n_estimators': [50, 100],
        'learning_rate': [0.1, 0.05],
        'max_depth': [3, 5]
    },
    'SVC': {
        'C': [0.1, 1, 5],
        'kernel': ['linear', 'rbf'],
        'gamma': ['scale', 'auto']
    },
    'KNN Classifier': {
        'n_neighbors': [3, 5, 7],
        'weights': ['uniform', 'distance']
    }
}

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import accuracy_score,classification_report

# %%
# hyperparameter tuning using GridSearchCV for multiple models and evaluating them based on accuracy and classification metrics.


result = []

for name in models:
    print(f'Tuning: {name}')
    grid = GridSearchCV(models[name], param_grid[name], cv=3, scoring='accuracy', n_jobs=-1)
    grid.fit(xtrain, ytrain)

    best_model = grid.best_estimator_
    y_pred = best_model.predict(xtest)
    print(f'{grid.best_params_}')
    acc = accuracy_score(ytest, y_pred)
    print(classification_report(ytest, y_pred))  # Optional detailed metrics

    result.append({
        'Model': name,
        'Best Params': grid.best_params_,
        'Test Accuracy': acc
    })
# Out:
# Tuning: Logistic Regression
# {'C': 1, 'penalty': 'l2', 'solver': 'lbfgs'}
#               precision    recall  f1-score   support
#
#            0       0.88      0.91      0.89     11713
#            1       0.88      0.84      0.86      9068
#
#     accuracy                           0.88     20781
#    macro avg       0.88      0.87      0.87     20781
# weighted avg       0.88      0.88      0.88     20781
#
# Tuning: Decision Tree Classifier
# {'max_depth': 20, 'min_samples_split': 10}
#               precision    recall  f1-score   support
#
#            0       0.95      0.96      0.96     11713
#            1       0.95      0.93      0.94      9068
#
#     accuracy                           0.95     20781
#    macro avg       0.95      0.95      0.95     20781
# weighted avg       0.95      0.95      0.95     20781
#
# Tuning: Random Forest Classifier
# {'max_depth': None, 'min_samples_split': 2, 'n_estimators': 100}
#               precision    recall  f1-score   support
# ...

# %%
results_df = pd.DataFrame(result)
results_df
# Out:
#                           Model  \
# 0           Logistic Regression
# 1      Decision Tree Classifier
# 2      Random Forest Classifier
# 3  Gradient Boosting Classifier
# 4                           SVC
# 5                KNN Classifier
#
#                                          Best Params  Test Accuracy
# 0       {'C': 1, 'penalty': 'l2', 'solver': 'lbfgs'}       0.877196
# 1         {'max_depth': 20, 'min_samples_split': 10}       0.950435
# 2  {'max_depth': None, 'min_samples_split': 2, 'n...       0.961648
# 3  {'learning_rate': 0.1, 'max_depth': 5, 'n_esti...       0.958568
# 4        {'C': 5, 'gamma': 'scale', 'kernel': 'rbf'}       0.957798
# 5          {'n_neighbors': 7, 'weights': 'distance'}       0.925942

# %%
best_model_idx = results_df['Test Accuracy'].idxmax()
worst_model_idx = results_df['Test Accuracy'].idxmin()

# %%
print("Best Performing Model:", results_df.loc[best_model_idx, 'Model'])
print("Worst Performing Model:", results_df.loc[worst_model_idx, 'Model'])
# Out:
# Best Performing Model: Random Forest Classifier
# Worst Performing Model: Logistic Regression

# %%
#Training Random Forest with Selected Hyperparameters and Evaluating Accuracy

m = RandomForestClassifier(max_depth=None, min_samples_split=5, n_estimators=50)
m.fit(xtrain, ytrain)
y_pred = m.predict(xtest)


print("Accuracy:", accuracy_score(ytest, y_pred))
# Out:
# Accuracy: 0.9622251094750012
